# %%
import pandas as pd

# Try loading the dataset
try:
    df = pd.read_csv("sales_data.csv")
    print("✅ Dataset loaded successfully!")
except FileNotFoundError:
    print("❌ sales_data.csv not found. Please make sure it's in the same folder as this notebook.")

# Show first 5 rows
df.head()
# Basic statistics of numerical columns
print("📊 Basic Statistics:")
print(df.describe())

# Check for missing values
print("\n🔍 Missing Values:")
print(df.isnull().sum())

# Group by Product and compute average sales
print("\n💡 Average Sales per Product:")
print(df.groupby("Product")["Sales"].mean())

# Group by Region and compute total sales
print("\n💡 Total Sales per Region:")
print(df.groupby("Region")["Sales"].sum())

# Explore dataset structure
print("📂 Dataset Info:")
print(df.info())

# Check if any missing values exist
print("\n🔍 Missing Values:")
print(df.isnull().sum())

# Compute overall statistics
print("\n📊 Statistics Summary:")
print(df.describe())

# Group by Product to find total sales
print("\n💡 Total Sales by Product:")
print(df.groupby("Product")["Sales"].sum())

# Group by Date to see daily sales
print("\n💡 Total Sales by Date:")
print(df.groupby("Date")["Sales"].sum())
# Out:
# ✅ Dataset loaded successfully!
# 📊 Basic Statistics:
#              Sales
# count    10.000000
# mean   1020.000000
# std     326.768692
# min     600.000000
# 25%     725.000000
# 50%    1025.000000
# 75%    1275.000000
# max    1500.000000
#
# 🔍 Missing Values:
# Date       0
# Product    0
# Region     0
# Sales      0
# dtype: int64
#
# 💡 Average Sales per Product:
# Product
# Laptop    1350.0
# Phone      950.0
# Tablet     650.0
# Name: Sales, dtype: float64
#
# 💡 Total Sales per Region:
# Region
# East     1900
# North    2800
# South    2900
# West     2600
# Name: Sales, dtype: int64
# 📂 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     10 non-null     object
#  1   Product  10 non-null     object
#  2   Region   10 non-null     object
#  3   Sales    10 non-null     int64
# dtypes: int64(1), object(3)
# ...

# %%
# Scatter: Sales vs DayNumber (numeric date) to get two numeric columns
df_sorted = df.sort_values("Date").reset_index(drop=True).copy()
start = df_sorted["Date"].min()
df_sorted["DayNumber"] = (df_sorted["Date"] - start).dt.days

plt.figure(figsize=(8,4))
plt.scatter(df_sorted["DayNumber"], df_sorted["Sales"])
plt.title("Sales vs Days since " + start.strftime("%Y-%m-%d"))
plt.xlabel("Days since " + start.strftime("%Y-%m-%d"))
plt.ylabel("Sales")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Scatter: Sales vs DayNumber (numeric date) to get two numeric columns
# ----> 2 df_sorted = df.sort_values("Date").reset_index(drop=True).copy()
#       3 start = df_sorted["Date"].min()
#       4 df_sorted["DayNumber"] = (df_sorted["Date"] - start).dt.days
#
# NameError: name 'df' is not defined

# %%
# Save line chart to file
daily_sales = df.groupby("Date")["Sales"].sum().sort_index()

plt.figure(figsize=(9,4))
plt.plot(daily_sales.index, daily_sales.values, marker="o", linestyle="-")
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("line_sales_over_time.png")
plt.close()

print("Saved: line_sales_over_time.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Save line chart to file
# ----> 2 daily_sales = df.groupby("Date")["Sales"].sum().sort_index()
#       4 plt.figure(figsize=(9,4))
#       5 plt.plot(daily_sales.index, daily_sales.values, marker="o", linestyle="-")
#
# NameError: name 'df' is not defined

# %%
import matplotlib
import seaborn
import pandas

print("All libraries installed successfully!")
# Out:
# All libraries installed successfully!

# %%
# Quick check: confirm dataframe exists and date column is datetime
import pandas as pd

# load if df not in memory
try:
    df
except NameError:
    df = pd.read_csv("sales_data.csv", parse_dates=["Date"])

print("Rows:", len(df))
print(df.dtypes)
df.head()
# Out:
# Rows: 10
# Date       object
# Product    object
# Region     object
# Sales       int64
# dtype: object
#          Date Product Region  Sales
# 0  2025-01-01  Laptop  North   1200
# 1  2025-01-02   Phone  South    800
# 2  2025-01-03  Tablet   East    600
# 3  2025-01-04  Laptop   West   1500
# 4  2025-01-05   Phone  North    950

# %%
# Setup plotting
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
# Line chart: total sales by date
daily_sales = df.groupby("Date")["Sales"].sum().sort_index()

plt.figure(figsize=(9,4))
plt.plot(daily_sales.index, daily_sales.values, marker="o", linestyle="-")
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Bar chart: total sales by product
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(7,4))
sns.barplot(x=product_sales.index, y=product_sales.values)
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
# Histogram: distribution of Sales values
plt.figure(figsize=(7,4))
plt.hist(df["Sales"], bins=8, edgecolor="black")
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Scatter: Sales vs DayNumber (numeric date) to get two numeric columns
df_sorted = df.sort_values("Date").reset_index(drop=True).copy()
start = df_sorted["Date"].min()
df_sorted["DayNumber"] = (df_sorted["Date"] - start).dt.days

plt.figure(figsize=(8,4))
plt.scatter(df_sorted["DayNumber"], df_sorted["Sales"])
plt.title("Sales vs Days since " + start.strftime("%Y-%m-%d"))
plt.xlabel("Days since " + start.strftime("%Y-%m-%d"))
plt.ylabel("Sales")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 df_sorted = df.sort_values("Date").reset_index(drop=True).copy()
#       3 start = df_sorted["Date"].min()
# ----> 4 df_sorted["DayNumber"] = (df_sorted["Date"] - start).dt.days
#       6 plt.figure(figsize=(8,4))
#       7 plt.scatter(df_sorted["DayNumber"], df_sorted["Sales"])
#
# ...
